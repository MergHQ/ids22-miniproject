# %% [markdown]
# # Combine all price, generation and load data into one dataframe

# %%
import pandas as pd

# %%
weather = pd.read_csv('./data/weather.csv')

# %%
import os

# %%
generation_first = pd.read_csv('./data/Actual Generation per Production Type_201501010000-201601010000.csv')

# %%
price_first = pd.read_csv('./data/Day-ahead Prices_201501010000-201601010000.csv')

# %%
load_first = pd.read_csv('./data/Total Load - Day Ahead _ Actual_201501010000-201601010000.csv')

# %%
generation = pd.DataFrame(columns = generation_first.columns)

# %%
price = pd.DataFrame(columns = price_first.columns)

# %%
load = pd.DataFrame(columns = load_first.columns)

# %%
import glob

# %%
generation_files = glob.glob('./data/Actual*')

# %%
generation_files.sort()

# %%
price_files = glob.glob('./data/Day*')
price_files.sort()

# %%
load_files = glob.glob('./data/Total*')
load_files.sort()

# %%
for file in generation_files:
    df = pd.read_csv(file)
    generation = pd.concat([generation, df], axis=0)
    #generation.merge(df, how='outer')

# %%
generation
# Out:
#         Area                                             MTU  \
# 0     BZN|FI  01.01.2015 00:00 - 01.01.2015 01:00 (CET/CEST)
# 1     BZN|FI  01.01.2015 01:00 - 01.01.2015 02:00 (CET/CEST)
# 2     BZN|FI  01.01.2015 02:00 - 01.01.2015 03:00 (CET/CEST)
# 3     BZN|FI  01.01.2015 03:00 - 01.01.2015 04:00 (CET/CEST)
# 4     BZN|FI  01.01.2015 04:00 - 01.01.2015 05:00 (CET/CEST)
# ...      ...                                             ...
# 8756  BZN|FI  31.12.2022 19:00 - 31.12.2022 20:00 (CET/CEST)
# 8757  BZN|FI  31.12.2022 20:00 - 31.12.2022 21:00 (CET/CEST)
# 8758  BZN|FI  31.12.2022 21:00 - 31.12.2022 22:00 (CET/CEST)
# 8759  BZN|FI  31.12.2022 22:00 - 31.12.2022 23:00 (CET/CEST)
# 8760  BZN|FI  31.12.2022 23:00 - 01.01.2023 00:00 (CET/CEST)
#
#      Biomass  - Actual Aggregated [MW]  \
# 0                                865.0
# 1                                874.0
# 2                                880.0
# 3                                872.0
# 4                                881.0
# ...                                ...
# 8756                                 -
# 8757                                 -
# 8758                                 -
# 8759                                 -
# 8760                                 -
#
#      Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                   n/e
# 1                                                   n/e
# 2                                                   n/e
# 3                                                   n/e
# 4                                                   n/e
# ...                                                 ...
# 8756                                                n/e
# 8757                                                n/e
# 8758                                                n/e
# 8759                                                n/e
# 8760                                                n/e
#
#      Fossil Coal-derived gas  - Actual Aggregated [MW]  \
# 0                                                  n/e
# 1                                                  n/e
# 2                                                  n/e
# 3                                                  n/e
# 4                                                  n/e
# ...                                                ...
# 8756                                               n/e
# 8757                                               n/e
# 8758                                               n/e
# 8759                                               n/e
# 8760                                               n/e
#
#      Fossil Gas  - Actual Aggregated [MW]  \
# 0                                   861.0
# 1                                   858.0
# 2                                   843.0
# 3                                   733.0
# 4                                   734.0
# ...                                   ...
# 8756                                    -
# 8757                                    -
# 8758                                    -
# 8759                                    -
# 8760                                    -
#
#      Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                         655.0
# 1                                         646.0
# 2                                         648.0
# 3                                         646.0
# 4                                         646.0
# ...                                         ...
# 8756                                          -
# 8757                                          -
# 8758                                          -
# 8759                                          -
# 8760                                          -
#
#      Fossil Oil  - Actual Aggregated [MW]  \
# 0                                     1.0
# 1                                     1.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
# ...                                   ...
# 8756                                    -
# 8757                                    -
# 8758                                    -
# 8759                                    -
# 8760                                    -
#
#      Fossil Oil shale  - Actual Aggregated [MW]  \
# 0                                           n/e
# 1                                           n/e
# 2                                           n/e
# 3                                           n/e
# 4                                           n/e
# ...                                         ...
# 8756                                        n/e
# 8757                                        n/e
# 8758                                        n/e
# 8759                                        n/e
# 8760                                        n/e
#
#      Fossil Peat  - Actual Aggregated [MW]  ...  \
# 0                                    396.0  ...
# 1                                    397.0  ...
# 2                                    396.0  ...
# 3                                    396.0  ...
# 4                                    399.0  ...
# ...                                    ...  ...
# 8756                                     -  ...
# 8757                                     -  ...
# 8758                                     -  ...
# 8759                                     -  ...
# 8760                                     -  ...
#
#      Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# 0                                                 735.0
# 1                                                 668.0
# 2                                                 669.0
# 3                                                 605.0
# 4                                                 594.0
# ...                                                 ...
# 8756                                                  -
# 8757                                                  -
# 8758                                                  -
# 8759                                                  -
# 8760                                                  -
#
#      Hydro Water Reservoir  - Actual Aggregated [MW]  \
# 0                                                n/e
# 1                                                n/e
# 2                                                n/e
# 3                                                n/e
# 4                                                n/e
# ...                                              ...
# 8756                                             n/e
# 8757                                             n/e
# 8758                                             n/e
# 8759                                             n/e
# 8760                                             n/e
#
#      Marine  - Actual Aggregated [MW] Nuclear  - Actual Aggregated [MW]  \
# 0                                 n/e                            2774.0
# 1                                 n/e                            2773.0
# 2                                 n/e                            2773.0
# 3                                 n/e                            2773.0
# 4                                 n/e                            2773.0
# ...                               ...                               ...
# 8756                              n/e                                 -
# 8757                              n/e                                 -
# 8758                              n/e                                 -
# 8759                              n/e                                 -
# 8760                              n/e                                 -
#
#      Other  - Actual Aggregated [MW]  \
# 0                              208.0
# 1                              208.0
# 2                              208.0
# 3                              208.0
# 4                              208.0
# ...                              ...
# 8756                               -
# 8757                               -
# 8758                               -
# 8759                               -
# 8760                               -
#
#      Other renewable  - Actual Aggregated [MW]  \
# 0                                         44.0
# 1                                         44.0
# 2                                         44.0
# 3                                         44.0
# 4                                         44.0
# ...                                        ...
# 8756                                         -
# 8757                                         -
# 8758                                         -
# 8759                                         -
# 8760                                         -
#
#      Solar  - Actual Aggregated [MW] Waste  - Actual Aggregated [MW]  \
# 0                                n/e                            55.0
# 1                                n/e                            49.0
# 2                                n/e                            47.0
# 3                                n/e                            47.0
# 4                                n/e                            45.0
# ...                              ...                             ...
# 8756                             n/e                               -
# 8757                             n/e                               -
# 8758                             n/e                               -
# 8759                             n/e                               -
# 8760                             n/e                               -
#
#      Wind Offshore  - Actual Aggregated [MW]  \
# 0                                        n/e
# 1                                        n/e
# 2                                        n/e
# 3                                        n/e
# 4                                        n/e
# ...                                      ...
# 8756                                     n/e
# 8757                                     n/e
# 8758                                     n/e
# 8759                                     n/e
# 8760                                     n/e
#
#      Wind Onshore  - Actual Aggregated [MW]
# 0                                     214.0
# 1                                     208.0
# 2                                     250.0
# 3                                     264.0
# 4                                     274.0
# ...                                     ...
# 8756                                      -
# 8757                                      -
# 8758                                      -
# 8759                                      -
# 8760                                      -
#
# [70136 rows x 23 columns]

# %%
for file in price_files:
    df = pd.read_csv(file)
    price = pd.concat([price, df], axis=0)
    #generation.merge(df, how='outer')

# %%
for file in load_files:
    df = pd.read_csv(file)
    load = pd.concat([load, df], axis=0)
    #generation.merge(df, how='outer')

# %%
price
# Out:
#                            MTU (CET/CEST) Day-ahead Price [EUR/MWh] Currency  \
# 0     01.01.2015 00:00 - 01.01.2015 01:00                     27.38      EUR
# 1     01.01.2015 01:00 - 01.01.2015 02:00                     23.37      EUR
# 2     01.01.2015 02:00 - 01.01.2015 03:00                     19.33      EUR
# 3     01.01.2015 03:00 - 01.01.2015 04:00                     17.66      EUR
# 4     01.01.2015 04:00 - 01.01.2015 05:00                     17.53      EUR
# ...                                   ...                       ...      ...
# 8756  31.12.2022 19:00 - 31.12.2022 20:00                         -      NaN
# 8757  31.12.2022 20:00 - 31.12.2022 21:00                         -      NaN
# 8758  31.12.2022 21:00 - 31.12.2022 22:00                         -      NaN
# 8759  31.12.2022 22:00 - 31.12.2022 23:00                         -      NaN
# 8760  31.12.2022 23:00 - 01.01.2023 00:00                         -      NaN
#
#       BZN|FI
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 8756     NaN
# 8757     NaN
# 8758     NaN
# 8759     NaN
# 8760     NaN
#
# [61375 rows x 4 columns]

# %%
load
# Out:
#                           Time (CET/CEST)  \
# 0     01.01.2015 00:00 - 01.01.2015 01:00
# 1     01.01.2015 01:00 - 01.01.2015 02:00
# 2     01.01.2015 02:00 - 01.01.2015 03:00
# 3     01.01.2015 03:00 - 01.01.2015 04:00
# 4     01.01.2015 04:00 - 01.01.2015 05:00
# ...                                   ...
# 8756  31.12.2022 19:00 - 31.12.2022 20:00
# 8757  31.12.2022 20:00 - 31.12.2022 21:00
# 8758  31.12.2022 21:00 - 31.12.2022 22:00
# 8759  31.12.2022 22:00 - 31.12.2022 23:00
# 8760  31.12.2022 23:00 - 01.01.2023 00:00
#
#      Day-ahead Total Load Forecast [MW] - BZN|FI  \
# 0                                         9122.0
# 1                                         8835.0
# 2                                         8668.0
# 3                                         8613.0
# 4                                         8685.0
# ...                                          ...
# 8756                                           -
# 8757                                           -
# 8758                                           -
# 8759                                           -
# 8760                                           -
#
#      Actual Total Load [MW] - BZN|FI
# 0                             9229.0
# 1                             8893.0
# 2                             8735.0
# 3                             8626.0
# 4                             8674.0
# ...                              ...
# 8756                               -
# 8757                               -
# 8758                               -
# 8759                               -
# 8760                               -
#
# [70136 rows x 3 columns]

# %%
price.to_csv('./data/all_pricedata.csv')

# %%
load.to_csv('./data/all_load_data.csv')

# %%
generation.to_csv('./data/all_generation_data.csv')

# %% [markdown]
# # Merge into one dataframe

# %%
generation.dtypes
# Out:
# Area                                                         object
# MTU                                                          object
# Biomass  - Actual Aggregated [MW]                            object
# Fossil Brown coal/Lignite  - Actual Aggregated [MW]          object
# Fossil Coal-derived gas  - Actual Aggregated [MW]            object
# Fossil Gas  - Actual Aggregated [MW]                         object
# Fossil Hard coal  - Actual Aggregated [MW]                   object
# Fossil Oil  - Actual Aggregated [MW]                         object
# Fossil Oil shale  - Actual Aggregated [MW]                   object
# Fossil Peat  - Actual Aggregated [MW]                        object
# Geothermal  - Actual Aggregated [MW]                         object
# Hydro Pumped Storage  - Actual Aggregated [MW]               object
# Hydro Pumped Storage  - Actual Consumption [MW]              object
# Hydro Run-of-river and poundage  - Actual Aggregated [MW]    object
# Hydro Water Reservoir  - Actual Aggregated [MW]              object
# Marine  - Actual Aggregated [MW]                             object
# Nuclear  - Actual Aggregated [MW]                            object
# Other  - Actual Aggregated [MW]                              object
# Other renewable  - Actual Aggregated [MW]                    object
# Solar  - Actual Aggregated [MW]                              object
# Waste  - Actual Aggregated [MW]                              object
# Wind Offshore  - Actual Aggregated [MW]                      object
# Wind Onshore  - Actual Aggregated [MW]                       object
# dtype: object

# %%
generation.MTU.str.replace('[(CET/CEST)].*','',  regex = True).str.strip()
# Out:
# 0       01.01.2015 00:00 - 01.01.2015 01:00
# 1       01.01.2015 01:00 - 01.01.2015 02:00
# 2       01.01.2015 02:00 - 01.01.2015 03:00
# 3       01.01.2015 03:00 - 01.01.2015 04:00
# 4       01.01.2015 04:00 - 01.01.2015 05:00
#                        ...
# 8756    31.12.2022 19:00 - 31.12.2022 20:00
# 8757    31.12.2022 20:00 - 31.12.2022 21:00
# 8758    31.12.2022 21:00 - 31.12.2022 22:00
# 8759    31.12.2022 22:00 - 31.12.2022 23:00
# 8760    31.12.2022 23:00 - 01.01.2023 00:00
# Name: MTU, Length: 70136, dtype: object

# %%
generation['MTU'] = generation.MTU.str.replace('[(CET/CEST)].*','',  regex = True).str.strip()

# %%
generation
# Out:
#         Area                                  MTU  \
# 0     BZN|FI  01.01.2015 00:00 - 01.01.2015 01:00
# 1     BZN|FI  01.01.2015 01:00 - 01.01.2015 02:00
# 2     BZN|FI  01.01.2015 02:00 - 01.01.2015 03:00
# 3     BZN|FI  01.01.2015 03:00 - 01.01.2015 04:00
# 4     BZN|FI  01.01.2015 04:00 - 01.01.2015 05:00
# ...      ...                                  ...
# 8756  BZN|FI  31.12.2022 19:00 - 31.12.2022 20:00
# 8757  BZN|FI  31.12.2022 20:00 - 31.12.2022 21:00
# 8758  BZN|FI  31.12.2022 21:00 - 31.12.2022 22:00
# 8759  BZN|FI  31.12.2022 22:00 - 31.12.2022 23:00
# 8760  BZN|FI  31.12.2022 23:00 - 01.01.2023 00:00
#
#      Biomass  - Actual Aggregated [MW]  \
# 0                                865.0
# 1                                874.0
# 2                                880.0
# 3                                872.0
# 4                                881.0
# ...                                ...
# 8756                                 -
# 8757                                 -
# 8758                                 -
# 8759                                 -
# 8760                                 -
#
#      Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                   n/e
# 1                                                   n/e
# 2                                                   n/e
# 3                                                   n/e
# 4                                                   n/e
# ...                                                 ...
# 8756                                                n/e
# 8757                                                n/e
# 8758                                                n/e
# 8759                                                n/e
# 8760                                                n/e
#
#      Fossil Coal-derived gas  - Actual Aggregated [MW]  \
# 0                                                  n/e
# 1                                                  n/e
# 2                                                  n/e
# 3                                                  n/e
# 4                                                  n/e
# ...                                                ...
# 8756                                               n/e
# 8757                                               n/e
# 8758                                               n/e
# 8759                                               n/e
# 8760                                               n/e
#
#      Fossil Gas  - Actual Aggregated [MW]  \
# 0                                   861.0
# 1                                   858.0
# 2                                   843.0
# 3                                   733.0
# 4                                   734.0
# ...                                   ...
# 8756                                    -
# 8757                                    -
# 8758                                    -
# 8759                                    -
# 8760                                    -
#
#      Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                         655.0
# 1                                         646.0
# 2                                         648.0
# 3                                         646.0
# 4                                         646.0
# ...                                         ...
# 8756                                          -
# 8757                                          -
# 8758                                          -
# 8759                                          -
# 8760                                          -
#
#      Fossil Oil  - Actual Aggregated [MW]  \
# 0                                     1.0
# 1                                     1.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
# ...                                   ...
# 8756                                    -
# 8757                                    -
# 8758                                    -
# 8759                                    -
# 8760                                    -
#
#      Fossil Oil shale  - Actual Aggregated [MW]  \
# 0                                           n/e
# 1                                           n/e
# 2                                           n/e
# 3                                           n/e
# 4                                           n/e
# ...                                         ...
# 8756                                        n/e
# 8757                                        n/e
# 8758                                        n/e
# 8759                                        n/e
# 8760                                        n/e
#
#      Fossil Peat  - Actual Aggregated [MW]  ...  \
# 0                                    396.0  ...
# 1                                    397.0  ...
# 2                                    396.0  ...
# 3                                    396.0  ...
# 4                                    399.0  ...
# ...                                    ...  ...
# 8756                                     -  ...
# 8757                                     -  ...
# 8758                                     -  ...
# 8759                                     -  ...
# 8760                                     -  ...
#
#      Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# 0                                                 735.0
# 1                                                 668.0
# 2                                                 669.0
# 3                                                 605.0
# 4                                                 594.0
# ...                                                 ...
# 8756                                                  -
# 8757                                                  -
# 8758                                                  -
# 8759                                                  -
# 8760                                                  -
#
#      Hydro Water Reservoir  - Actual Aggregated [MW]  \
# 0                                                n/e
# 1                                                n/e
# 2                                                n/e
# 3                                                n/e
# 4                                                n/e
# ...                                              ...
# 8756                                             n/e
# 8757                                             n/e
# 8758                                             n/e
# 8759                                             n/e
# 8760                                             n/e
#
#      Marine  - Actual Aggregated [MW] Nuclear  - Actual Aggregated [MW]  \
# 0                                 n/e                            2774.0
# 1                                 n/e                            2773.0
# 2                                 n/e                            2773.0
# 3                                 n/e                            2773.0
# 4                                 n/e                            2773.0
# ...                               ...                               ...
# 8756                              n/e                                 -
# 8757                              n/e                                 -
# 8758                              n/e                                 -
# 8759                              n/e                                 -
# 8760                              n/e                                 -
#
#      Other  - Actual Aggregated [MW]  \
# 0                              208.0
# 1                              208.0
# 2                              208.0
# 3                              208.0
# 4                              208.0
# ...                              ...
# 8756                               -
# 8757                               -
# 8758                               -
# 8759                               -
# 8760                               -
#
#      Other renewable  - Actual Aggregated [MW]  \
# 0                                         44.0
# 1                                         44.0
# 2                                         44.0
# 3                                         44.0
# 4                                         44.0
# ...                                        ...
# 8756                                         -
# 8757                                         -
# 8758                                         -
# 8759                                         -
# 8760                                         -
#
#      Solar  - Actual Aggregated [MW] Waste  - Actual Aggregated [MW]  \
# 0                                n/e                            55.0
# 1                                n/e                            49.0
# 2                                n/e                            47.0
# 3                                n/e                            47.0
# 4                                n/e                            45.0
# ...                              ...                             ...
# 8756                             n/e                               -
# 8757                             n/e                               -
# 8758                             n/e                               -
# 8759                             n/e                               -
# 8760                             n/e                               -
#
#      Wind Offshore  - Actual Aggregated [MW]  \
# 0                                        n/e
# 1                                        n/e
# 2                                        n/e
# 3                                        n/e
# 4                                        n/e
# ...                                      ...
# 8756                                     n/e
# 8757                                     n/e
# 8758                                     n/e
# 8759                                     n/e
# 8760                                     n/e
#
#      Wind Onshore  - Actual Aggregated [MW]
# 0                                     214.0
# 1                                     208.0
# 2                                     250.0
# 3                                     264.0
# 4                                     274.0
# ...                                     ...
# 8756                                      -
# 8757                                      -
# 8758                                      -
# 8759                                      -
# 8760                                      -
#
# [70136 rows x 23 columns]

# %%
generation.iloc[0, 1] == load.iloc[0, 0]
# Out:
# True

# %%
generation.iloc[0, 1]
# Out:
# '01.01.2015 00:00 - 01.01.2015 01:00'

# %%
load.iloc[0, 0]
# Out:
# '01.01.2015 00:00 - 01.01.2015 01:00'

# %% [markdown]
# The timestamps seem to be in the same format so I can just merge them based on the time.

# %%
generation.iloc[0, 1] == price.iloc[0, 0]
# Out:
# True

# %%
df = generation.merge(load, how='outer', left_on = 'MTU', right_on = 'Time (CET/CEST)')

# %%
df = df.merge(price, how='outer', left_on = 'MTU', right_on = 'MTU (CET/CEST)')

# %%
df.head()
# Out:
#      Area                                  MTU  \
# 0  BZN|FI  01.01.2015 00:00 - 01.01.2015 01:00
# 1  BZN|FI  01.01.2015 01:00 - 01.01.2015 02:00
# 2  BZN|FI  01.01.2015 02:00 - 01.01.2015 03:00
# 3  BZN|FI  01.01.2015 03:00 - 01.01.2015 04:00
# 4  BZN|FI  01.01.2015 04:00 - 01.01.2015 05:00
#
#   Biomass  - Actual Aggregated [MW]  \
# 0                             865.0
# 1                             874.0
# 2                             880.0
# 3                             872.0
# 4                             881.0
#
#   Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                n/e
# 1                                                n/e
# 2                                                n/e
# 3                                                n/e
# 4                                                n/e
#
#   Fossil Coal-derived gas  - Actual Aggregated [MW]  \
# 0                                               n/e
# 1                                               n/e
# 2                                               n/e
# 3                                               n/e
# 4                                               n/e
#
#   Fossil Gas  - Actual Aggregated [MW]  \
# 0                                861.0
# 1                                858.0
# 2                                843.0
# 3                                733.0
# 4                                734.0
#
#   Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                      655.0
# 1                                      646.0
# 2                                      648.0
# 3                                      646.0
# 4                                      646.0
#
#   Fossil Oil  - Actual Aggregated [MW]  \
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
#
#   Fossil Oil shale  - Actual Aggregated [MW]  \
# 0                                        n/e
# 1                                        n/e
# 2                                        n/e
# 3                                        n/e
# 4                                        n/e
#
#   Fossil Peat  - Actual Aggregated [MW]  ... Waste  - Actual Aggregated [MW]  \
# 0                                 396.0  ...                            55.0
# 1                                 397.0  ...                            49.0
# 2                                 396.0  ...                            47.0
# 3                                 396.0  ...                            47.0
# 4                                 399.0  ...                            45.0
#
#   Wind Offshore  - Actual Aggregated [MW]  \
# 0                                     n/e
# 1                                     n/e
# 2                                     n/e
# 3                                     n/e
# 4                                     n/e
#
#   Wind Onshore  - Actual Aggregated [MW]                      Time (CET/CEST)  \
# 0                                  214.0  01.01.2015 00:00 - 01.01.2015 01:00
# 1                                  208.0  01.01.2015 01:00 - 01.01.2015 02:00
# 2                                  250.0  01.01.2015 02:00 - 01.01.2015 03:00
# 3                                  264.0  01.01.2015 03:00 - 01.01.2015 04:00
# 4                                  274.0  01.01.2015 04:00 - 01.01.2015 05:00
#
#   Day-ahead Total Load Forecast [MW] - BZN|FI Actual Total Load [MW] - BZN|FI  \
# 0                                      9122.0                          9229.0
# 1                                      8835.0                          8893.0
# 2                                      8668.0                          8735.0
# 3                                      8613.0                          8626.0
# 4                                      8685.0                          8674.0
#
#                         MTU (CET/CEST) Day-ahead Price [EUR/MWh] Currency  \
# 0  01.01.2015 00:00 - 01.01.2015 01:00                     27.38      EUR
# 1  01.01.2015 01:00 - 01.01.2015 02:00                     23.37      EUR
# 2  01.01.2015 02:00 - 01.01.2015 03:00                     19.33      EUR
# 3  01.01.2015 03:00 - 01.01.2015 04:00                     17.66      EUR
# 4  01.01.2015 04:00 - 01.01.2015 05:00                     17.53      EUR
#
#   BZN|FI
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 30 columns]

# %%
len(df[df['BZN|FI'].isna() == False])
# Out:
# 0

# %% [markdown]
# There is no valid information in BZN|FI

# %%
len(generation.index)
# Out:
# 70136

# %%
len(df.index)
# Out:
# 70180

# %%
len(price.index)
# Out:
# 61375

# %%
len(load.index)
# Out:
# 70136

# %% [markdown]
# There seem to be some dates for which there is missing information in prices and also some days for which there is more info in prices or loads than in generation.

# %%
df.iloc[0, 4] == 'n/e'
# Out:
# True

# %% [markdown]
# Let's replace all n/e values with np.nan

# %%
import numpy as np

# %%
for column in df.columns:
    df.loc[df[column] == 'n/e', column] = np.nan
    df.loc[df[column] == '-', column] = np.nan

# %%
df
# Out:
#          Area                                  MTU  \
# 0      BZN|FI  01.01.2015 00:00 - 01.01.2015 01:00
# 1      BZN|FI  01.01.2015 01:00 - 01.01.2015 02:00
# 2      BZN|FI  01.01.2015 02:00 - 01.01.2015 03:00
# 3      BZN|FI  01.01.2015 03:00 - 01.01.2015 04:00
# 4      BZN|FI  01.01.2015 04:00 - 01.01.2015 05:00
# ...       ...                                  ...
# 70175  BZN|FI  31.12.2022 19:00 - 31.12.2022 20:00
# 70176  BZN|FI  31.12.2022 20:00 - 31.12.2022 21:00
# 70177  BZN|FI  31.12.2022 21:00 - 31.12.2022 22:00
# 70178  BZN|FI  31.12.2022 22:00 - 31.12.2022 23:00
# 70179  BZN|FI  31.12.2022 23:00 - 01.01.2023 00:00
#
#       Biomass  - Actual Aggregated [MW]  \
# 0                                 865.0
# 1                                 874.0
# 2                                 880.0
# 3                                 872.0
# 4                                 881.0
# ...                                 ...
# 70175                               NaN
# 70176                               NaN
# 70177                               NaN
# 70178                               NaN
# 70179                               NaN
#
#       Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 70175                                                NaN
# 70176                                                NaN
# 70177                                                NaN
# 70178                                                NaN
# 70179                                                NaN
#
#       Fossil Coal-derived gas  - Actual Aggregated [MW]  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 70175                                               NaN
# 70176                                               NaN
# 70177                                               NaN
# 70178                                               NaN
# 70179                                               NaN
#
#       Fossil Gas  - Actual Aggregated [MW]  \
# 0                                    861.0
# 1                                    858.0
# 2                                    843.0
# 3                                    733.0
# 4                                    734.0
# ...                                    ...
# 70175                                  NaN
# 70176                                  NaN
# 70177                                  NaN
# 70178                                  NaN
# 70179                                  NaN
#
#       Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                          655.0
# 1                                          646.0
# 2                                          648.0
# 3                                          646.0
# 4                                          646.0
# ...                                          ...
# 70175                                        NaN
# 70176                                        NaN
# 70177                                        NaN
# 70178                                        NaN
# 70179                                        NaN
#
#       Fossil Oil  - Actual Aggregated [MW]  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# ...                                    ...
# 70175                                  NaN
# 70176                                  NaN
# 70177                                  NaN
# 70178                                  NaN
# 70179                                  NaN
#
#       Fossil Oil shale  - Actual Aggregated [MW]  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 70175                                        NaN
# 70176                                        NaN
# 70177                                        NaN
# 70178                                        NaN
# 70179                                        NaN
#
#       Fossil Peat  - Actual Aggregated [MW]  ...  \
# 0                                     396.0  ...
# 1                                     397.0  ...
# 2                                     396.0  ...
# 3                                     396.0  ...
# 4                                     399.0  ...
# ...                                     ...  ...
# 70175                                   NaN  ...
# 70176                                   NaN  ...
# 70177                                   NaN  ...
# 70178                                   NaN  ...
# 70179                                   NaN  ...
#
#       Waste  - Actual Aggregated [MW] Wind Offshore  - Actual Aggregated [MW]  \
# 0                                55.0                                     NaN
# 1                                49.0                                     NaN
# 2                                47.0                                     NaN
# 3                                47.0                                     NaN
# 4                                45.0                                     NaN
# ...                               ...                                     ...
# 70175                             NaN                                     NaN
# 70176                             NaN                                     NaN
# 70177                             NaN                                     NaN
# 70178                             NaN                                     NaN
# 70179                             NaN                                     NaN
#
#       Wind Onshore  - Actual Aggregated [MW]  \
# 0                                      214.0
# 1                                      208.0
# 2                                      250.0
# 3                                      264.0
# 4                                      274.0
# ...                                      ...
# 70175                                    NaN
# 70176                                    NaN
# 70177                                    NaN
# 70178                                    NaN
# 70179                                    NaN
#
#                            Time (CET/CEST)  \
# 0      01.01.2015 00:00 - 01.01.2015 01:00
# 1      01.01.2015 01:00 - 01.01.2015 02:00
# 2      01.01.2015 02:00 - 01.01.2015 03:00
# 3      01.01.2015 03:00 - 01.01.2015 04:00
# 4      01.01.2015 04:00 - 01.01.2015 05:00
# ...                                    ...
# 70175  31.12.2022 19:00 - 31.12.2022 20:00
# 70176  31.12.2022 20:00 - 31.12.2022 21:00
# 70177  31.12.2022 21:00 - 31.12.2022 22:00
# 70178  31.12.2022 22:00 - 31.12.2022 23:00
# 70179  31.12.2022 23:00 - 01.01.2023 00:00
#
#       Day-ahead Total Load Forecast [MW] - BZN|FI  \
# 0                                          9122.0
# 1                                          8835.0
# 2                                          8668.0
# 3                                          8613.0
# 4                                          8685.0
# ...                                           ...
# 70175                                         NaN
# 70176                                         NaN
# 70177                                         NaN
# 70178                                         NaN
# 70179                                         NaN
#
#       Actual Total Load [MW] - BZN|FI                       MTU (CET/CEST)  \
# 0                              9229.0  01.01.2015 00:00 - 01.01.2015 01:00
# 1                              8893.0  01.01.2015 01:00 - 01.01.2015 02:00
# 2                              8735.0  01.01.2015 02:00 - 01.01.2015 03:00
# 3                              8626.0  01.01.2015 03:00 - 01.01.2015 04:00
# 4                              8674.0  01.01.2015 04:00 - 01.01.2015 05:00
# ...                               ...                                  ...
# 70175                             NaN  31.12.2022 19:00 - 31.12.2022 20:00
# 70176                             NaN  31.12.2022 20:00 - 31.12.2022 21:00
# 70177                             NaN  31.12.2022 21:00 - 31.12.2022 22:00
# 70178                             NaN  31.12.2022 22:00 - 31.12.2022 23:00
# 70179                             NaN  31.12.2022 23:00 - 01.01.2023 00:00
#
#       Day-ahead Price [EUR/MWh] Currency BZN|FI
# 0                         27.38      EUR    NaN
# 1                         23.37      EUR    NaN
# 2                         19.33      EUR    NaN
# 3                         17.66      EUR    NaN
# 4                         17.53      EUR    NaN
# ...                         ...      ...    ...
# 70175                       NaN      NaN    NaN
# 70176                       NaN      NaN    NaN
# 70177                       NaN      NaN    NaN
# 70178                       NaN      NaN    NaN
# 70179                       NaN      NaN    NaN
#
# [70180 rows x 30 columns]

# %% [markdown]
# Calculate the number of missing values in each column:

# %%
for column in df.columns:
    print('number of missing values in column', column)
    print(df[column].isna().sum())
# Out:
# number of missing values in column Area
# 0
# number of missing values in column MTU
# 0
# number of missing values in column Biomass  - Actual Aggregated [MW]
# 2393
# number of missing values in column Fossil Brown coal/Lignite  - Actual Aggregated [MW]
# 70180
# number of missing values in column Fossil Coal-derived gas  - Actual Aggregated [MW]
# 70180
# number of missing values in column Fossil Gas  - Actual Aggregated [MW]
# 2395
# number of missing values in column Fossil Hard coal  - Actual Aggregated [MW]
# 2395
# number of missing values in column Fossil Oil  - Actual Aggregated [MW]
# 2397
# number of missing values in column Fossil Oil shale  - Actual Aggregated [MW]
# 70180
# number of missing values in column Fossil Peat  - Actual Aggregated [MW]
# 2394
# number of missing values in column Geothermal  - Actual Aggregated [MW]
# 70180
# number of missing values in column Hydro Pumped Storage  - Actual Aggregated [MW]
# 70180
# number of missing values in column Hydro Pumped Storage  - Actual Consumption [MW]
# 70180
# number of missing values in column Hydro Run-of-river and poundage  - Actual Aggregated [MW]
# 2395
# number of missing values in column Hydro Water Reservoir  - Actual Aggregated [MW]
# 70180
# number of missing values in column Marine  - Actual Aggregated [MW]
# 70180
# number of missing values in column Nuclear  - Actual Aggregated [MW]
# 2391
# number of missing values in column Other  - Actual Aggregated [MW]
# 2395
# number of missing values in column Other renewable  - Actual Aggregated [MW]
# 2395
# number of missing values in column Solar  - Actual Aggregated [MW]
# 70180
# number of missing values in column Waste  - Actual Aggregated [MW]
# 2393
# number of missing values in column Wind Offshore  - Actual Aggregated [MW]
# 70180
# number of missing values in column Wind Onshore  - Actual Aggregated [MW]
# 2391
# number of missing values in column Time (CET/CEST)
# 0
# number of missing values in column Day-ahead Total Load Forecast [MW] - BZN|FI
# 2344
# number of missing values in column Actual Total Load [MW] - BZN|FI
# 2377
# number of missing values in column MTU (CET/CEST)
# 8763
# number of missing values in column Day-ahead Price [EUR/MWh]
# 11081
# number of missing values in column Currency
# 11079
# number of missing values in column BZN|FI
# 70180

# %% [markdown]
# There are 8763 values in df for which there is no price data available.

# %% [markdown]
# Remove all columns that contain no other data than NaN values:

# %%
for column in df.columns:
    if df[column].isna().sum() == len(df.index):
        print('drop column', column)
        df.drop(columns = column, inplace = True)
# Out:
# drop column Fossil Brown coal/Lignite  - Actual Aggregated [MW]
# drop column Fossil Coal-derived gas  - Actual Aggregated [MW]
# drop column Fossil Oil shale  - Actual Aggregated [MW]
# drop column Geothermal  - Actual Aggregated [MW]
# drop column Hydro Pumped Storage  - Actual Aggregated [MW]
# drop column Hydro Pumped Storage  - Actual Consumption [MW]
# drop column Hydro Water Reservoir  - Actual Aggregated [MW]
# drop column Marine  - Actual Aggregated [MW]
# drop column Solar  - Actual Aggregated [MW]
# drop column Wind Offshore  - Actual Aggregated [MW]
# drop column BZN|FI

# %%
df
# Out:
#          Area                                  MTU  \
# 0      BZN|FI  01.01.2015 00:00 - 01.01.2015 01:00
# 1      BZN|FI  01.01.2015 01:00 - 01.01.2015 02:00
# 2      BZN|FI  01.01.2015 02:00 - 01.01.2015 03:00
# 3      BZN|FI  01.01.2015 03:00 - 01.01.2015 04:00
# 4      BZN|FI  01.01.2015 04:00 - 01.01.2015 05:00
# ...       ...                                  ...
# 70175  BZN|FI  31.12.2022 19:00 - 31.12.2022 20:00
# 70176  BZN|FI  31.12.2022 20:00 - 31.12.2022 21:00
# 70177  BZN|FI  31.12.2022 21:00 - 31.12.2022 22:00
# 70178  BZN|FI  31.12.2022 22:00 - 31.12.2022 23:00
# 70179  BZN|FI  31.12.2022 23:00 - 01.01.2023 00:00
#
#       Biomass  - Actual Aggregated [MW] Fossil Gas  - Actual Aggregated [MW]  \
# 0                                 865.0                                861.0
# 1                                 874.0                                858.0
# 2                                 880.0                                843.0
# 3                                 872.0                                733.0
# 4                                 881.0                                734.0
# ...                                 ...                                  ...
# 70175                               NaN                                  NaN
# 70176                               NaN                                  NaN
# 70177                               NaN                                  NaN
# 70178                               NaN                                  NaN
# 70179                               NaN                                  NaN
#
#       Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                          655.0
# 1                                          646.0
# 2                                          648.0
# 3                                          646.0
# 4                                          646.0
# ...                                          ...
# 70175                                        NaN
# 70176                                        NaN
# 70177                                        NaN
# 70178                                        NaN
# 70179                                        NaN
#
#       Fossil Oil  - Actual Aggregated [MW]  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# ...                                    ...
# 70175                                  NaN
# 70176                                  NaN
# 70177                                  NaN
# 70178                                  NaN
# 70179                                  NaN
#
#       Fossil Peat  - Actual Aggregated [MW]  \
# 0                                     396.0
# 1                                     397.0
# 2                                     396.0
# 3                                     396.0
# 4                                     399.0
# ...                                     ...
# 70175                                   NaN
# 70176                                   NaN
# 70177                                   NaN
# 70178                                   NaN
# 70179                                   NaN
#
#       Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# 0                                                  735.0
# 1                                                  668.0
# 2                                                  669.0
# 3                                                  605.0
# 4                                                  594.0
# ...                                                  ...
# 70175                                                NaN
# 70176                                                NaN
# 70177                                                NaN
# 70178                                                NaN
# 70179                                                NaN
#
#       Nuclear  - Actual Aggregated [MW] Other  - Actual Aggregated [MW]  \
# 0                                2774.0                           208.0
# 1                                2773.0                           208.0
# 2                                2773.0                           208.0
# 3                                2773.0                           208.0
# 4                                2773.0                           208.0
# ...                                 ...                             ...
# 70175                               NaN                             NaN
# 70176                               NaN                             NaN
# 70177                               NaN                             NaN
# 70178                               NaN                             NaN
# 70179                               NaN                             NaN
#
#       Other renewable  - Actual Aggregated [MW]  \
# 0                                          44.0
# 1                                          44.0
# 2                                          44.0
# 3                                          44.0
# 4                                          44.0
# ...                                         ...
# 70175                                       NaN
# 70176                                       NaN
# 70177                                       NaN
# 70178                                       NaN
# 70179                                       NaN
#
#       Waste  - Actual Aggregated [MW] Wind Onshore  - Actual Aggregated [MW]  \
# 0                                55.0                                  214.0
# 1                                49.0                                  208.0
# 2                                47.0                                  250.0
# 3                                47.0                                  264.0
# 4                                45.0                                  274.0
# ...                               ...                                    ...
# 70175                             NaN                                    NaN
# 70176                             NaN                                    NaN
# 70177                             NaN                                    NaN
# 70178                             NaN                                    NaN
# 70179                             NaN                                    NaN
#
#                            Time (CET/CEST)  \
# 0      01.01.2015 00:00 - 01.01.2015 01:00
# 1      01.01.2015 01:00 - 01.01.2015 02:00
# 2      01.01.2015 02:00 - 01.01.2015 03:00
# 3      01.01.2015 03:00 - 01.01.2015 04:00
# 4      01.01.2015 04:00 - 01.01.2015 05:00
# ...                                    ...
# 70175  31.12.2022 19:00 - 31.12.2022 20:00
# 70176  31.12.2022 20:00 - 31.12.2022 21:00
# 70177  31.12.2022 21:00 - 31.12.2022 22:00
# 70178  31.12.2022 22:00 - 31.12.2022 23:00
# 70179  31.12.2022 23:00 - 01.01.2023 00:00
#
#       Day-ahead Total Load Forecast [MW] - BZN|FI  \
# 0                                          9122.0
# 1                                          8835.0
# 2                                          8668.0
# 3                                          8613.0
# 4                                          8685.0
# ...                                           ...
# 70175                                         NaN
# 70176                                         NaN
# 70177                                         NaN
# 70178                                         NaN
# 70179                                         NaN
#
#       Actual Total Load [MW] - BZN|FI                       MTU (CET/CEST)  \
# 0                              9229.0  01.01.2015 00:00 - 01.01.2015 01:00
# 1                              8893.0  01.01.2015 01:00 - 01.01.2015 02:00
# 2                              8735.0  01.01.2015 02:00 - 01.01.2015 03:00
# 3                              8626.0  01.01.2015 03:00 - 01.01.2015 04:00
# 4                              8674.0  01.01.2015 04:00 - 01.01.2015 05:00
# ...                               ...                                  ...
# 70175                             NaN  31.12.2022 19:00 - 31.12.2022 20:00
# 70176                             NaN  31.12.2022 20:00 - 31.12.2022 21:00
# 70177                             NaN  31.12.2022 21:00 - 31.12.2022 22:00
# 70178                             NaN  31.12.2022 22:00 - 31.12.2022 23:00
# 70179                             NaN  31.12.2022 23:00 - 01.01.2023 00:00
#
#       Day-ahead Price [EUR/MWh] Currency
# 0                         27.38      EUR
# 1                         23.37      EUR
# 2                         19.33      EUR
# 3                         17.66      EUR
# 4                         17.53      EUR
# ...                         ...      ...
# 70175                       NaN      NaN
# 70176                       NaN      NaN
# 70177                       NaN      NaN
# 70178                       NaN      NaN
# 70179                       NaN      NaN
#
# [70180 rows x 19 columns]

# %% [markdown]
# Create a timestamp from MTU so that I can drop all rows after the date for which we have no data available.

# %%
df['start_time'] = df.MTU.str.split('-', expand = True)[0].str.strip()

# %%
df['end_time'] = df.MTU.str.split('-', expand = True)[1].str.strip()

# %%
df.head()
# Out:
#      Area                                  MTU  \
# 0  BZN|FI  01.01.2015 00:00 - 01.01.2015 01:00
# 1  BZN|FI  01.01.2015 01:00 - 01.01.2015 02:00
# 2  BZN|FI  01.01.2015 02:00 - 01.01.2015 03:00
# 3  BZN|FI  01.01.2015 03:00 - 01.01.2015 04:00
# 4  BZN|FI  01.01.2015 04:00 - 01.01.2015 05:00
#
#   Biomass  - Actual Aggregated [MW] Fossil Gas  - Actual Aggregated [MW]  \
# 0                             865.0                                861.0
# 1                             874.0                                858.0
# 2                             880.0                                843.0
# 3                             872.0                                733.0
# 4                             881.0                                734.0
#
#   Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                      655.0
# 1                                      646.0
# 2                                      648.0
# 3                                      646.0
# 4                                      646.0
#
#   Fossil Oil  - Actual Aggregated [MW] Fossil Peat  - Actual Aggregated [MW]  \
# 0                                  1.0                                 396.0
# 1                                  1.0                                 397.0
# 2                                  1.0                                 396.0
# 3                                  1.0                                 396.0
# 4                                  1.0                                 399.0
#
#   Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# 0                                              735.0
# 1                                              668.0
# 2                                              669.0
# 3                                              605.0
# 4                                              594.0
#
#   Nuclear  - Actual Aggregated [MW] Other  - Actual Aggregated [MW]  ...  \
# 0                            2774.0                           208.0  ...
# 1                            2773.0                           208.0  ...
# 2                            2773.0                           208.0  ...
# 3                            2773.0                           208.0  ...
# 4                            2773.0                           208.0  ...
#
#   Waste  - Actual Aggregated [MW] Wind Onshore  - Actual Aggregated [MW]  \
# 0                            55.0                                  214.0
# 1                            49.0                                  208.0
# 2                            47.0                                  250.0
# 3                            47.0                                  264.0
# 4                            45.0                                  274.0
#
#                        Time (CET/CEST)  \
# 0  01.01.2015 00:00 - 01.01.2015 01:00
# 1  01.01.2015 01:00 - 01.01.2015 02:00
# 2  01.01.2015 02:00 - 01.01.2015 03:00
# 3  01.01.2015 03:00 - 01.01.2015 04:00
# 4  01.01.2015 04:00 - 01.01.2015 05:00
#
# 67864                                   NaN
# 67865                                   NaN
# 67866                                   NaN
# 67867                                   NaN
# 67868                                   NaN
# 67869                                   NaN
# 67870                                   NaN
# 67871                                   NaN
# 67872                                   NaN
# 67873                                   NaN
# 67874                                   NaN
# 67875                                   NaN
# 67876                                   NaN
# 67877                                   NaN
# 67878                                   NaN
# 67879                                   NaN
# 67880                                   NaN
# 67881                                   NaN
# 67882                                   NaN
# 67883                                   NaN
# 67884                                   NaN
# 67885                                   NaN
# 67886                                   NaN
# 67887                                   NaN
# 67888                                   NaN
# 67889                                   NaN
# 67890                                   NaN
# 67891                                   NaN
# 67892                                   NaN
# 67893                                   NaN
# 67894                                   NaN
# 67895                                   NaN
# 67896                                   NaN
# 67897                                   NaN
# 67898                                   NaN
# 67899                                   NaN
# 67900                                   NaN
# 67901                                   NaN
# 67902                                   NaN
# 67903                                   NaN
# 67904                                   NaN
# 67905                                   NaN
# 67906                                   NaN
# 67907                                   NaN
# 67908                                   NaN
#
#       Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# 67859                                                962
# 67860                                                NaN
# 67861                                                NaN
# 67862                                                NaN
# 67863                                                NaN
# 67864                                                NaN
# 67865                                                NaN
# 67866                                                NaN
# 67867                                                NaN
# 67868                                                NaN
# 67869                                                NaN
# 67870                                                NaN
# 67871                                                NaN
# 67872                                                NaN
# 67873                                                NaN
# 67874                                                NaN
# 67875                                                NaN
# 67876                                                NaN
# 67877                                                NaN
# 67878                                                NaN
# 67879                                                NaN
# 67880                                                NaN
# 67881                                                NaN
# 67882                                                NaN
# 67883                                                NaN
# 67884                                                NaN
# 67885                                                NaN
# 67886                                                NaN
# 67887                                                NaN
# 67888                                                NaN
# 67889                                                NaN
# 67890                                                NaN
# 67891                                                NaN
# 67892                                                NaN
# 67893                                                NaN
# 67894                                                NaN
# 67895                                                NaN
# 67896                                                NaN
# 67897                                                NaN
# 67898                                                NaN
# 67899                                                NaN
# 67900                                                NaN
# 67901                                                NaN
# 67902                                                NaN
# 67903                                                NaN
# 67904                                                NaN
# 67905                                                NaN
# 67906                                                NaN
# 67907                                                NaN
# 67908                                                NaN
#
#       Nuclear  - Actual Aggregated [MW] Other  - Actual Aggregated [MW]  ...  \
# 67859                              3726                              55  ...
# 67860                               NaN                             NaN  ...
# 67861                               NaN                             NaN  ...
# 67862                               NaN                             NaN  ...
# 67863                               NaN                             NaN  ...
# 67864                               NaN                             NaN  ...
# 67865                               NaN                             NaN  ...
# 67866                               NaN                             NaN  ...
# 67867                               NaN                             NaN  ...
# 67868                               NaN                             NaN  ...
# 67869                               NaN                             NaN  ...
# 67870                               NaN                             NaN  ...
# 67871                               NaN                             NaN  ...
# 67872                               NaN                             NaN  ...
# 67873                               NaN                             NaN  ...
# 67874                               NaN                             NaN  ...
# 67875                               NaN                             NaN  ...
# 67876                               NaN                             NaN  ...
# 67877                               NaN                             NaN  ...
# 67878                               NaN                             NaN  ...
# 67879                               NaN                             NaN  ...
# 67880                               NaN                             NaN  ...
# 67881                               NaN                             NaN  ...
# 67882                               NaN                             NaN  ...
# 67855  BZN|FI  26.09.2022 10:00 - 26.09.2022 11:00
# 67856  BZN|FI  26.09.2022 11:00 - 26.09.2022 12:00
# 67857  BZN|FI  26.09.2022 12:00 - 26.09.2022 13:00
# 67858  BZN|FI  26.09.2022 13:00 - 26.09.2022 14:00
# 67859  BZN|FI  26.09.2022 14:00 - 26.09.2022 15:00
#
#       Biomass  - Actual Aggregated [MW] Fossil Gas  - Actual Aggregated [MW]  \
# 0                                 865.0                                861.0
# 1                                 874.0                                858.0
# 2                                 880.0                                843.0
# 3                                 872.0                                733.0
# 4                                 881.0                                734.0
# ...                                 ...                                  ...
# 67855                               808                                  150
# 67856                               808                                  159
# 67857                               802                                  175
# 67858                               811                                  161
# 67859                               810                                  142
#
#       Fossil Hard coal  - Actual Aggregated [MW]  \
# 0                                          655.0
# 1                                          646.0
# 2                                          648.0
# 3                                          646.0
# 4                                          646.0
# ...                                          ...
# 67855                                        331
# 67856                                        345
# 67857                                        331
# 67858                                        322
# 67859                                        318
#
#       Fossil Oil  - Actual Aggregated [MW]  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# ...                                    ...
# 67855                                    2
# 67856                                    2
# 67857                                    0
# 67858                                    0
# 67859                                    1
#
#       Fossil Peat  - Actual Aggregated [MW]  \
# 0                                     396.0
# 1                                     397.0
# 2                                     396.0
# 3                                     396.0
# 4                                     399.0
# ...                                     ...
# 67855                                   235
# 67856                                   225
# 67857                                   223
# 67858                                   225
# 67859                                   222
#
#       Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# 0                                                  735.0
# 1                                                  668.0
# 2                                                  669.0
# 3                                                  605.0
# 4                                                  594.0
# ...                                                  ...
# 67855                                               1334
# 67856                                               1261
# 67857                                               1078
# 67858                                               1033
# 67859                                                962
#
#       Nuclear  - Actual Aggregated [MW] Other  - Actual Aggregated [MW]  ...  \
# 0                                2774.0                           208.0  ...
# 1                                2773.0                           208.0  ...
# 2                                2773.0                           208.0  ...
# 3                                2773.0                           208.0  ...
# 4                                2773.0                           208.0  ...
# ...                                 ...                             ...  ...
# 67855                              3728                              51  ...
# 67856                              3728                              49  ...
# 67857                              3726                              52  ...
# 67858                              3728                              59  ...
# 67859                              3726                              55  ...
#
#       Waste  - Actual Aggregated [MW] Wind Onshore  - Actual Aggregated [MW]  \
# 0                                55.0                                  214.0
# 1                                49.0                                  208.0
# 2                                47.0                                  250.0
# 3                                47.0                                  264.0
# 4                                45.0                                  274.0
# ...                               ...                                    ...
# 67855                              23                                    639
# 67856                              23                                    676
# 67857                              24                                    700
# 67858                              23                                    726
# 67859                              23                                    711
#
#                            Time (CET/CEST)  \
# 0      01.01.2015 00:00 - 01.01.2015 01:00
# 1      01.01.2015 01:00 - 01.01.2015 02:00
# 2      01.01.2015 02:00 - 01.01.2015 03:00
# 3      01.01.2015 03:00 - 01.01.2015 04:00
# 4      01.01.2015 04:00 - 01.01.2015 05:00
# ...                                    ...
# 67855  26.09.2022 10:00 - 26.09.2022 11:00
# 67856  26.09.2022 11:00 - 26.09.2022 12:00
# 67857  26.09.2022 12:00 - 26.09.2022 13:00
# 67858  26.09.2022 13:00 - 26.09.2022 14:00
# 67859  26.09.2022 14:00 - 26.09.2022 15:00
#
#       Day-ahead Total Load Forecast [MW] - BZN|FI  \
# 0                                          9122.0
# 1                                          8835.0
# 2                                          8668.0
# 3                                          8613.0
# 4                                          8685.0
# ...                                           ...
# 67855                                        8599
# 67856                                        8538
# 67857                                        8465
# 67858                                        8428
# 67859                                        8375
#
#       Actual Total Load [MW] - BZN|FI                       MTU (CET/CEST)  \
# 0                              9229.0  01.01.2015 00:00 - 01.01.2015 01:00
# 1                              8893.0  01.01.2015 01:00 - 01.01.2015 02:00
# 2                              8735.0  01.01.2015 02:00 - 01.01.2015 03:00
# 3                              8626.0  01.01.2015 03:00 - 01.01.2015 04:00
# 4                              8674.0  01.01.2015 04:00 - 01.01.2015 05:00
# ...                               ...                                  ...
# 67855                            8809  26.09.2022 10:00 - 26.09.2022 11:00
# 67856                            8787  26.09.2022 11:00 - 26.09.2022 12:00
# 67857                            8713  26.09.2022 12:00 - 26.09.2022 13:00
# 67858                            8634  26.09.2022 13:00 - 26.09.2022 14:00
# 67859                            8562  26.09.2022 14:00 - 26.09.2022 15:00
#
#       Day-ahead Price [EUR/MWh] Currency          start_time  \
# 0                         27.38      EUR 2015-01-01 00:00:00
# 1                         23.37      EUR 2015-01-01 01:00:00
# 2                         19.33      EUR 2015-01-01 02:00:00
# 3                         17.66      EUR 2015-01-01 03:00:00
# 4                         17.53      EUR 2015-01-01 04:00:00
# ...                         ...      ...                 ...
# 67855                    284.65      EUR 2022-09-26 10:00:00
# 67856                    272.90      EUR 2022-09-26 11:00:00
# 67857                    275.75      EUR 2022-09-26 12:00:00
# 67858                    283.92      EUR 2022-09-26 13:00:00
# 67859                    283.97      EUR 2022-09-26 14:00:00
#
#                  end_time
# 0     2015-01-01 01:00:00
# 1     2015-01-01 02:00:00
# 2     2015-01-01 03:00:00
# 3     2015-01-01 04:00:00
# 4     2015-01-01 05:00:00
# ...                   ...
# 67855 2022-09-26 11:00:00
# 67856 2022-09-26 12:00:00
# 67857 2022-09-26 13:00:00
# 67858 2022-09-26 14:00:00
# 67859 2022-09-26 15:00:00
#
# [67860 rows x 21 columns]

# %% [markdown]
# # Draw plots on the data

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.head(50).MTU, df.head(50)['Day-ahead Price [EUR/MWh]'])

# %%
df.columns
# Out:
# Index(['Area', 'MTU', 'Biomass  - Actual Aggregated [MW]',
#        'Fossil Gas  - Actual Aggregated [MW]',
#        'Fossil Hard coal  - Actual Aggregated [MW]',
#        'Fossil Oil  - Actual Aggregated [MW]',
#        'Fossil Peat  - Actual Aggregated [MW]',
#        'Hydro Run-of-river and poundage  - Actual Aggregated [MW]',
#        'Nuclear  - Actual Aggregated [MW]', 'Other  - Actual Aggregated [MW]',
#        'Other renewable  - Actual Aggregated [MW]',
#        'Waste  - Actual Aggregated [MW]',
#        'Wind Onshore  - Actual Aggregated [MW]', 'Time (CET/CEST)',
#        'Day-ahead Total Load Forecast [MW] - BZN|FI',
#        'Actual Total Load [MW] - BZN|FI', 'MTU (CET/CEST)',
#        'Day-ahead Price [EUR/MWh]', 'Currency', 'start_time', 'end_time'],
#       dtype='object')

# %%
df['start_time_day'] = df['start_time'].dt.date
# Out:
# /tmp/ipykernel_14843/1683599061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_time_day'] = df['start_time'].dt.date

# %%
df.dtypes
# Out:
# Area                                                                 object
# MTU                                                                  object
# Biomass  - Actual Aggregated [MW]                                    object
# Fossil Gas  - Actual Aggregated [MW]                                 object
# Fossil Hard coal  - Actual Aggregated [MW]                           object
# Fossil Oil  - Actual Aggregated [MW]                                 object
# Fossil Peat  - Actual Aggregated [MW]                                object
# Hydro Run-of-river and poundage  - Actual Aggregated [MW]            object
# Nuclear  - Actual Aggregated [MW]                                    object
# Other  - Actual Aggregated [MW]                                      object
# Other renewable  - Actual Aggregated [MW]                            object
# Waste  - Actual Aggregated [MW]                                      object
# Wind Onshore  - Actual Aggregated [MW]                               object
# Time (CET/CEST)                                                      object
# Day-ahead Total Load Forecast [MW] - BZN|FI                          object
# Actual Total Load [MW] - BZN|FI                                      object
# MTU (CET/CEST)                                                       object
# Day-ahead Price [EUR/MWh]                                            object
# Currency                                                             object
# start_time                                                   datetime64[ns]
# end_time                                                     datetime64[ns]
# start_time_day                                                       object
# dtype: object

# %%
df['Actual Total Load [MW] - BZN|FI'] = pd.to_numeric(df['Actual Total Load [MW] - BZN|FI'])
# Out:
# /tmp/ipykernel_14843/2637970014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Actual Total Load [MW] - BZN|FI'] = pd.to_numeric(df['Actual Total Load [MW] - BZN|FI'])

# %%
df['Day-ahead Price [EUR/MWh]'] = pd.to_numeric(df['Day-ahead Price [EUR/MWh]'])
# Out:
# /tmp/ipykernel_14843/2391199815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day-ahead Price [EUR/MWh]'] = pd.to_numeric(df['Day-ahead Price [EUR/MWh]'])

# %%
df['Fossil Oil  - Actual Aggregated [MW]'] = pd.to_numeric(df['Fossil Oil - Actual Aggregated [MW]'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fossil Oil - Actual Aggregated [MW]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 df['Fossil Oil  - Actual Aggregated [MW]'] = pd.to_numeric(df['Fossil Oil - Actual Aggregated [MW]'])
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Fossil Oil - Actual Aggregated [MW]'

# %%
df.columns
# Out:
# Index(['Area', 'MTU', 'Biomass  - Actual Aggregated [MW]',
#        'Fossil Gas  - Actual Aggregated [MW]',
#        'Fossil Hard coal  - Actual Aggregated [MW]',
#        'Fossil Oil  - Actual Aggregated [MW]',
#        'Fossil Peat  - Actual Aggregated [MW]',
#        'Hydro Run-of-river and poundage  - Actual Aggregated [MW]',
#        'Nuclear  - Actual Aggregated [MW]', 'Other  - Actual Aggregated [MW]',
#        'Other renewable  - Actual Aggregated [MW]',
#        'Waste  - Actual Aggregated [MW]',
#        'Wind Onshore  - Actual Aggregated [MW]', 'Time (CET/CEST)',
#        'Day-ahead Total Load Forecast [MW] - BZN|FI',
#        'Actual Total Load [MW] - BZN|FI', 'MTU (CET/CEST)',
#        'Day-ahead Price [EUR/MWh]', 'Currency', 'start_time', 'end_time',
#        'start_time_day'],
#       dtype='object')

# %%
means = df.groupby('start_time_day', as_index=False).agg({'Day-ahead Price [EUR/MWh]':'mean', 'Actual Total Load [MW] - BZN|FI':'mean', 'Fossil Oil - Actual Aggregated [MW]':'mean'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 means = df.groupby('start_time_day', as_index=False).agg({'Day-ahead Price [EUR/MWh]':'mean', 'Actual Total Load [MW] - BZN|FI':'mean', 'Fossil Oil - Actual Aggregated [MW]':'mean'})
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/groupby/generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/apply.py:473, in Apply.agg_dict_like(self)
#     470     selected_obj = obj._selected_obj
#     471     selection = obj._selection
# --> 473 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     475 if selected_obj.ndim == 1:
#     476     # key only used for output
#     477     colg = obj._gotitem(selection, ndim=1)
#
# File ~/.conda/envs/work_env/lib/python3.10/site-packages/pandas/core/apply.py:591, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     589     if len(cols) > 0:
#     590         cols_sorted = list(safe_sort(list(cols)))
# --> 591         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     593 is_aggregator = lambda x: isinstance(x, (list, tuple, dict))
#     595 # if we have a dict of any non-scalars
#     596 # eg. {'A' : ['mean']}, normalize all to
#     597 # be list-likes
#     598 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Fossil Oil - Actual Aggregated [MW]'] do not exist"

# %%
means

# %%
plt.plot(means.start_time_day, means['Day-ahead Price [EUR/MWh]'])

# %% [markdown]
# The prices seem to change a lot. Additionally, there is no data available for year 2016. This is probably just an accident and I will fix it.

# %%
plt.plot(means.start_time_day, means['Actual Total Load [MW] - BZN|FI'])

# %%
plt.plot(means.start_time_day, means['Fossil Oil - Actual Aggregated [MW]'])

# %% [markdown]
# The first months of 2022 seem interesting.

# %%
df.loc[(df['start_time'] > pd.Timestamp('2022-01-01')) & (df['start_time'] < pd.Timestamp('2022-01-31'))]

# %%
df.loc[(df['start_time'] > pd.Timestamp('2022-04-01')) & (df['start_time'] < pd.Timestamp('2022-04-30'))]

# %% [markdown]
# It seems like until some point in April 2022 the value has always been set to 10. The values of fossil fuel seem somewhat weird overall as they are very stable.

# %%
df.drop(columns = ['Time (CET/CEST)', 'MTU (CET/CEST)'], inplace = True)

# %%
df
